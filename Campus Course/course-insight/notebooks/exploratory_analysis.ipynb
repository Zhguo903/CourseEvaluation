# %% [markdown]
# # CourseInsight Exploratory Analysis
#
# Run `python run_pipeline.py` before using this notebook.

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
courses = pd.read_csv(root / 'data/processed/courses_clean.csv')
reviews = pd.read_csv(root / 'data/processed/reviews_clean.csv')
courses.head(), reviews.head()

# %%
reviews[['rating', 'difficulty', 'workload', 'usefulness']].describe()
